# %%
import os
import re
import pandas as pd
import configparser
import jaconv
from tqdm import tqdm
import math

# %%
config = configparser.ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %% [markdown]
# # データ読み込み

# %%
OUTPUT_ROOT = config.get("Output","output_path")
cookpad_edges_path = os.path.join(OUTPUT_ROOT,"output_csv/cookpad_edges.csv") 
rakuten_edges_path = os.path.join(OUTPUT_ROOT,"output_csv/rakuten_edges.csv") 
seibunhyo_edges_path = os.path.join(OUTPUT_ROOT,"output_csv/seibunhyo_edges.csv") 

cookpad_edges = pd.read_csv(cookpad_edges_path)
rakuten_edges = pd.read_csv(rakuten_edges_path)
seibunhyo_edges = pd.read_csv(seibunhyo_edges_path)

# %%
print(len(cookpad_edges))
print(len(rakuten_edges))
print(len(seibunhyo_edges))
# Out:
# 12724374
# 5273415
# 266023

# %%
rakuten_edges
# Out:
#                                          recipe_id recipe_title  \
# 0         ad7d585b06850f8437ff5fb97d3c7a823ff21bb1         豚の角煮
# 1         ad7d585b06850f8437ff5fb97d3c7a823ff21bb1         豚の角煮
# 2         ad7d585b06850f8437ff5fb97d3c7a823ff21bb1         豚の角煮
# 3         ad7d585b06850f8437ff5fb97d3c7a823ff21bb1         豚の角煮
# 4         ad7d585b06850f8437ff5fb97d3c7a823ff21bb1         豚の角煮
# ...                                            ...          ...
# 12724369  7a9d10ab5eb506a3e66b0e115a1ce84b0dfe7a39     豆もやしのなむる
# 12724370  7a9d10ab5eb506a3e66b0e115a1ce84b0dfe7a39     豆もやしのなむる
# 12724371  7a9d10ab5eb506a3e66b0e115a1ce84b0dfe7a39     豆もやしのなむる
# 12724372  7a9d10ab5eb506a3e66b0e115a1ce84b0dfe7a39     豆もやしのなむる
# 12724373  7a9d10ab5eb506a3e66b0e115a1ce84b0dfe7a39     豆もやしのなむる
#
#          ingredient_name          edge_type data_source
# 0                   しょうが  recipe-ingredient     cookpad
# 1                   にんにく  recipe-ingredient     cookpad
# 2                     ねぎ  recipe-ingredient     cookpad
# 3                     豚肉  recipe-ingredient     cookpad
# 4                     砂糖  recipe-ingredient     cookpad
# ...                  ...                ...         ...
# 12724369            豆もやし  recipe-ingredient     cookpad
# 12724370               塩  recipe-ingredient     cookpad
# 12724371             ごま油  recipe-ingredient     cookpad
# 12724372              醤油  recipe-ingredient     cookpad
# 12724373     にんにく(すりおろし)  recipe-ingredient     cookpad
#
# [12724374 rows x 5 columns]

# %%
import rdflib
import uuid
from rdflib import Graph, Namespace, URIRef, BNode, Literal, RDF, RDFS
import os

g = Graph()
# 名前空間の定義
RECIPE = Namespace("http://JapaneseFoodKG.org/Recipe/")
INGREDIENT = Namespace("http://JapaneseFoodKG.org/Ingredient/")
NUTRITION = Namespace("http://JapaneseFoodKG.org/Nutrition/")
DATA_SOURCE = Namespace("http://JapaneseFoodKG.org/data_source/")
RELATION = Namespace("http://JapaneseFoodKG.org/relation/")

# %%
ingredient_uris = {}

# %%
ingredient_uris = {}
for index, row in tqdm(cookpad_edges.iterrows(),total=len(cookpad_edges)):
    recipe_id = row['recipe_id']
    recipe_title = row['recipe_title']
    ingredient_name = row['ingredient_name']
    data_source = row['data_source']
    
    
    # レシピに関する情報を追加
    recipe_uri = RECIPE[recipe_id]
    g.add((recipe_uri, RDF.type, RECIPE.Recipe))
    g.add((recipe_uri, RECIPE.title, Literal(recipe_title)))
    g.add((recipe_uri, DATA_SOURCE.source, Literal(data_source)))  # データソースをレシピに追加
    
    
    # 食材のURI（文字列が一致する場合は既存のURIを使用）
    if ingredient_name not in ingredient_uris:
        random_uuid = str(uuid.uuid4())
        ingredient_uris[ingredient_name] = INGREDIENT[random_uuid]
    ingredient_uri = ingredient_uris[ingredient_name]

    # 食材に関する情報を追加
    g.add((ingredient_uri, RDF.type, INGREDIENT.Ingredient))
    g.add((ingredient_uri, INGREDIENT.name, Literal(ingredient_name)))

    # レシピと食材の関係を追加
    g.add((recipe_uri, RECIPE.hasIngredient, ingredient_uri))
# Out:
#   1%|          | 153870/12724374 [00:19<31:48, 6586.05it/s]http://JapaneseFoodKG.org/Recipe/{Ａ}しょうゆ does not look like a valid URI, trying to serialize this will break.
# http://JapaneseFoodKG.org/Recipe/{Ａ}砂糖 does not look like a valid URI, trying to serialize this will break.
# http://JapaneseFoodKG.org/Recipe/{Ａ}酒 does not look like a valid URI, trying to serialize this will break.
# 100%|██████████| 12724374/12724374 [30:16<00:00, 7004.97it/s]

# %%
for index, row in tqdm(rakuten_edges.iterrows(),total=len(rakuten_edges)):
    recipe_id = row['recipe_id']
    recipe_title = row['recipe_title']
    ingredient_name = row['ingredient_name']
    data_source = row['data_source']
    
    # レシピに関する情報を追加
    recipe_uri = RECIPE[recipe_id]
    g.add((recipe_uri, RDF.type, RECIPE.Recipe))
    g.add((recipe_uri, RECIPE.title, Literal(recipe_title)))
    g.add((recipe_uri, DATA_SOURCE.source, Literal(data_source)))  # データソースをレシピに追加
    
    
    # 食材のURI（文字列が一致する場合は既存のURIを使用）
    if ingredient_name not in ingredient_uris:
        random_uuid = str(uuid.uuid4())
        ingredient_uris[ingredient_name] = INGREDIENT[random_uuid]
    ingredient_uri = ingredient_uris[ingredient_name]

    # 食材に関する情報を追加
    g.add((ingredient_uri, RDF.type, INGREDIENT.Ingredient))
    g.add((ingredient_uri, INGREDIENT.name, Literal(ingredient_name)))

    # レシピと食材の関係を追加
    g.add((recipe_uri, RECIPE.hasIngredient, ingredient_uri))
# Out:
# 100%|██████████| 5273415/5273415 [12:28<00:00, 7045.59it/s]

# %%
from rdflib.namespace import XSD


nutrition_uris = {}

for index, row in tqdm(seibunhyo_edges.iterrows(),total=len(seibunhyo_edges)):
    food_name = row['food_name']
    nutrition_name = row['nutrition_name']
    value = row['value']
    data_source = row['data_source']  # データソースの値を取得

    # 栄養素のURI（文字列が一致する場合は既存のURIを使用）
    if nutrition_name not in nutrition_uris:
        # ランダムなUUIDを生成
        random_uuid = str(uuid.uuid4())
        nutrition_uris[nutrition_name] = NUTRITION[random_uuid]
    nutrition_uri = nutrition_uris[nutrition_name]
    # 栄養素に関する情報を追加
    g.add((nutrition_uri, RDF.type, NUTRITION.Nutrient))
    g.add((nutrition_uri, NUTRITION.name, Literal(nutrition_name)))
    
    food_name = food_name.replace('\u3000', ' ')  # 全角スペースを半角スペースに置換
    matching_ingredients = {name: uri for name, uri in ingredient_uris.items() if isinstance(name, str) and name in food_name}


    for ingredient_name, ingredient_uri in matching_ingredients.items():
        relation_uri = RELATION[str(uuid.uuid4())]  # エッジのURI
        g.add((ingredient_uri, relation_uri, nutrition_uri))
        g.add((relation_uri, RDF.type, RELATION.Contains))
        g.add((relation_uri, RELATION.value, Literal(value, datatype=XSD.float)))
        g.add((relation_uri, DATA_SOURCE.source, Literal(data_source)))
# Out:
#  15%|█▌        | 40127/266023 [00:03<00:17, 12632.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb セル 11 line 1
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> nutrition_uri = nutrition_uris[nutrition_name]
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> # 栄養素に関する情報を追加
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> g.add((nutrition_uri, RDF.type, NUTRITION.Nutrient))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> g.add((nutrition_uri, NUTRITION.name, Literal(nutrition_name)))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yoshimaru/Japanese-FoodKG-master/src/create_rdf_files.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> food_name = food_name.replace('\u3000', ' ')  # 全角スペースを半角スペースに置換
#
# File ~/Japanese-FoodKG-master/.venv/lib/python3.10/site-packages/rdflib/graph.py:527, in Graph.add(self, triple)
#     520     """Close the graph store
#     521
#     522     Might be necessary for stores that require closing a connection to a
#     523     database or releasing some resource.
#     524     """
#     525     return self.__store.close(commit_pending_transaction=commit_pending_transaction)
# --> 527 def add(self: _GraphT, triple: "_TripleType") -> _GraphT:
#     528     """Add a triple with self as context"""
#     529     s, p, o = triple
#
# KeyboardInterrupt:

# %% [markdown]
# # rdfファイル出力

# %%
japanesefoodkg_path = os.path.join(OUTPUT_ROOT,"JapaneseFoodKG.ttl") 
# RDFを保存（例としてTurtle形式で出力）
with open(japanesefoodkg_path, "wb") as f:
    f.write(g.serialize(format="turtle"))

# %%
ingredient_uris
# Out:
# {'しょうが': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/97e50983-cece-483e-b975-47790efc4189'),
#  'にんにく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/02e59014-c279-42b9-bcdb-db4d8d6a9e47'),
#  'ねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8fb3a4d2-68ad-4cc8-97a1-136d40dd792b'),
#  '豚肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/21ec4a8c-63e4-45ca-a080-b700f7101ebd'),
#  '砂糖': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/424db96d-6963-475d-b84a-211921257b7c'),
#  '酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bc7f6d3b-8215-4877-a782-feb8c8b41b2b'),
#  '醤油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/13e79813-93a6-411e-8d07-eac3d188d537'),
#  'みりん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7af1b8a3-9328-48cf-896d-e06b6b30b71b'),
#  'にんじん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/380e0813-6b49-4ae7-8e84-12735324e443'),
#  'ぴーまん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0ee429d9-8ceb-4d54-b4a0-5c0b6d7f957c'),
#  'れんこん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a0419f36-7a6d-46b3-9a4c-bb1985fd722d'),
#  'おろしだれ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b3d63e3a-b714-4121-ac2e-18e6e569053d'),
#  'こしょう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/79ba4a7e-c499-484f-977d-76047ba71dcb'),
#  '塩': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/43af857d-b414-439f-b97f-a0dff03745ce'),
#  'たまねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/
ーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/41a18f41-e8cc-45b0-bd81-513f50b5d1b3'),
#  'ぶりとそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5e30d291-44cd-400e-94ae-7187dd8dc270'),
#  'ばじる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4e6261ce-da5e-4914-9555-b946e21d50e0'),
#  'とろけるちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a9382a13-0c31-429c-9940-d14af8ef538a'),
#  'こーんすたーち': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/54028f9c-f4ae-47c1-804f-66761990e474'),
#  'こんでんすみるく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0dfe7cbb-432b-4814-827f-c0b87ff28ce9'),
#  '水飴': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8d50091c-36ce-4197-9e0f-2eddc13fbc5c'),
#  'すいーとちょこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fba1aaed-599f-4312-a01a-d980a863d242'),
#  '豆板醤': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6115328d-3c37-41a9-8f2f-32f064676291'),
#  'ぱん粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4063d316-59fc-4120-a84b-92a86784a5d3'),
#  '里芋': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/857a9fc2-3b5d-4ca0-ad81-ed7d40eb33ef'),
#  '油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d2aba47d-e7f3-497c-9b2b-ed6a8e391fdb'),
#  'べーこん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bab890f4-edb5-4515-be3d-151f2637a6f6'),
#  'とうがらしの葉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a72e0c96-7864-48de-a321-621a95cfd524'),
#  'あぼがど': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/48a9f108-c219-497d-918a-496c21b95e9a'),
#  'おれがの': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e2d040ed-c97f-40a2-b735-600798afceef'),
#  'あずき缶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f0167d7e-86a5-4764-b550-3b1da1cc1176'),
#  'ほたて貝柱缶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4ca2b3f3-b454-41f8-820d-d4970fb7fae8'),
#  '黒こしょう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d1534825-8f16-4831-8fc9-4a9d99faafc1'),
#  '水煮大豆': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c4179c25-71c6-475c-ab6c-1530ae834c87'),
#  '豚のすぺありぶ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4a883416-a7a4-4833-bce5-eba323751b37'),
#  '五香粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/27e04f31-c9c2-4f94-b1b4-7ae3871485ef'),
#  'おいすたーそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/121310cc-1f0e-4df3-8cb0-52803f6b5705'),
#  '圧力鍋': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/96d138af-b234-4b6f-b486-02e3fe3d3723'),
#  '鶏胸肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/14936127-6740-45e8-b3c3-fb471efcc944'),
#  'ぱるめざんちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b00fc43c-cf7f-4d40-b534-0ccfdd12432a'),
#  'たらごん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9770005c-5500-468c-9f6f-1243771ffc43'),
#  '鶏がらすーぷ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f6fc0f96-9c95-40a8-bb9c-64e7d3cae0cb'),
#  'せろり': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4e5e0504-304f-4715-abf6-0a1ab0b06329'),
#  'ひき肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ee4d4ea5-c160-4aa2-ab2f-3648a9a499a1'),
#  'ぱせり': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9601e0dd-54ad-47fd-a497-a39a673e582c'),
#  '月桂樹の葉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b05749f7-824f-453e-8b43-a8ea48016675'),
#  'こんそめの素': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c151fcac-a81d-474d-9878-f19b2416be1c'),
#  'ろーずまりー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ef48bd20-3eaf-4a46-b3b2-f7715d72f1e7'),
#  'くれいじーそると': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e5b22e07-b384-4aae-9211-e4d902861c6c'),
#  'くらっかー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bf743eee-eda5-47b3-be70-846abddd2d14'),
#  'あさり': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a1bc1d2b-8dae-480a-b280-2e3c62d5502a'),
#  'まっしゅるーむ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1fed25d4-501b-4676-986e-5672d8415bc7'),
#  '鶏もも肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0c612aeb-b403-4a61-84b6-0cb9e756e748'),
#  'きくらげ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d854b880-899f-48ad-ac1f-3f608aa7b7d0'),
#  'ざーさい': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3bf77df0-49f6-4785-ac69-e53863cfb0c5'),
#  '薄力粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/
': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2a7911d3-756b-4d50-823f-69ca79168c7d'),
#  'ぱせり（6枝）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/219edaa7-6bfd-45ab-b301-cb053449cf51'),
#  'ろーりえ（2枚）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0f8e2bbc-e35c-4c7d-9aff-a05e3b82cf2a'),
#  'たいむ（3枝）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/03e804b6-5d2b-4b24-af5c-83c5b52c1a02'),
#  'せろりの葉っぱ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2060f7e9-9975-436e-8b1f-00fdd54d8e5d'),
#  'おりーぶおいる（適量）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9c2f6b87-d9db-4296-adb3-06bfffc67c26'),
#  'さんきすとれもん（瓶詰め）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ea7eaf29-60e0-4fa7-8cc0-edb39c25fe65'),
#  '胡椒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8bf01f49-4e78-46b4-a03a-3ea9de87c84e'),
#  '白わいん（１かっぷ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/83e8bb43-494c-433a-a585-e2c21b5bd21f'),
#  'ぱすた': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/61e62d53-1f9e-4e50-a56e-8a1c40db40b9'),
#  '粉ちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1c051e79-9b5b-4847-9bc4-77b17f24a4cf'),
#  'ぶらっくぺっぱー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c95265e7-8a46-4ecf-bcbf-30ecf8623828'),
#  'ろーりえ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/87e32e28-e696-4809-82c3-5774733b3e3f'),
#  '卵黄': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a80f0308-4674-4265-b1fd-2e10111157f0'),
#  'しょーとぶれっど': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ba57047b-c657-4ac4-b6bd-6b4eac71f230'),
#  '全粒粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6902fabf-afd1-471f-9248-91caea3324f5'),
#  '粉砂糖': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/525ac87a-373d-4583-b5c5-e3f8986d7c7a'),
#  '青柳': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/94c28957-e6eb-4b12-a35f-bf03daa00e87'),
#  '白ねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0d171e23-89cd-4e25-ac8b-f950f3aefbf1'),
#  'とり肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/effd1cec-d02f-4ffe-8765-0f481ddbd720'),
#  '生姜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d602f0c6-261f-475b-ac2c-448a00e256a4'),
#  'お酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ea8fe73a-f22c-4d1c-a191-7ecd5c9dc72e'),
#  '皮付き鶏もも肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4d4fc92e-511e-4975-b21d-28b2cdfb03b0'),
#  '大蒜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/65aedf4f-efe0-41e2-a89e-93840e564208'),
#  '生姜汁': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6ff110ce-e96c-4ad0-b944-e76d4a837b50'),
#  '乾しあんず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/eb2b2b89-97f6-41d0-b147-671a77557f35'),
#  '招興酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/602e9c19-6fcf-4249-876e-207f9a94fb26'),
#  '牡蠣油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/de99a7f8-1f31-40ef-a54e-d72e8a88076a'),
#  'かたくり粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c6be1d45-1e9d-4bd8-a20d-48320328fa17'),
#  '松の実': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0ff9e0e4-5342-44c6-8c12-0eb0ad2d4786'),
#  'ぺこりーのちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/87e7d760-1a22-44aa-8d39-a974054e1c46'),
#  'ささ身': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/860755de-b897-4c85-8807-45f5366e2dd7'),
#  'らー油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b3286b28-17f8-4ec2-ba11-c99b42a33107'),
#  '顆粒だしの素': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6a25e4da-aea3-49fa-bb10-59fada61226e'),
#  '豚肉の切り落とし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b6dbd482-5d8b-4618-aa97-fc293763d514'),
#  'からし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f8b1553b-2e0a-44dd-8a69-03793482226a'),
#  '枝豆': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e9d1658f-860d-4005-bdf5-c8010bedc8ad'),
#  '梅干に入っているしそ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/08dbe593-ed30-41fc-a8ea-d2985232c2fd'),
#  '昆布（出汁用）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bd734f74-0f62-4e77-bf2e-9685f28e57f2'),
#  '米': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/87cd48bc-036f-4b7c-8b0d-a3054bd6081e'),
#  'きんめ鯛': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cf944410-2e85-4ca6-84b9-eaf96250ff11'),
#  '木綿豆腐': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/62473fc6-9cd8-42e4-b196-221c28a40d4f'),
#  '青ねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/65324e41-48a8-424a-83b6-b9d24fbe1810'),
#  '土生姜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3c0b3861-bb81-4a2f-b062-dbd8c5d63905'),
#  '日本酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/06dd0efa-19e4-449a-865f-fc7998c1203f'),
#  'さつまいも': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/deeb217c-2fef-404a-ab86-03e29510d07b'),
#  'ぱいなっぷる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/461a7de5-142f-4a77-8983-cbd6d50e6aff'),
#  'りんご': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5261aae8-0f6b-4ee9-a4eb-cbff73f45043'),
#  'きうい': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8c19b3e2-050b-4f14-8338-2502244157bd'),
#  'ぱいんの缶汁': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/51001edb-2d5d-4e3a-8d07-1178932d3f4f'),
#  'さとう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a98709a8-6689-43b7-aa62-ab049d2fb246'),
#  '重曹': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/57d81fe9-a131-4861-acbc-eea7f742e8a9'),
#  'どらいふるーつ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/934998c8-b7a6-4c76-865d-0815657e3cab'),
#  '地鶏もも肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c76fc38d-746e-4dca-a251-4cd07cf5ccfe'),
#  'じゃがいも（またはさつまいも）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/10c3e492-7f88-4092-bde8-495643b9f2f8'),
#  '粉唐辛子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/83084979-b28f-482b-bf2f-d27220755325'),
#  'すりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/acd57f49-871f-40f3-b54d-5416b2f04f7b'),
#  'ごはん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a8914ff6-30cb-444f-80ff-3e6d13dd4095'),
#  '韓国のり': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f1d6f878-5f0e-46b5-ad1d-c8556b4a59a8'),
#  '炊き立てご飯': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d9149b11-5df7-4a4a-9b71-45c9ed4e0d67'),
#  'おくら': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/80bca788-0e8f-4a16-91c6-0255c568fda4'),
#  'どれっしんぐ(のんおいる青じそor和風)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/883dbcc5-55e5-4f85-ab4f-71163935c21d'),
#  'そうめん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cc84b38e-f6f8-4940-94d6-ddd8c6ae835e'),
#  '残り物の天ぷら': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d8013cb0-ab7b-4989-83be-ef2ba8cceca3'),
#  'しそ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/59166d2b-35df-4a43-9156-25a6d312b215'),
#  'ちーず適量': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ae238899-24ee-4de6-97ab-c2549b0779a6'),
#  'ぎょうざの皮': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e6e51f72-2c00-47ad-8853-620d3209c9f7'),
#  '里芋（生でも、冷凍でも可）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b7dc5b43-3d83-4d0b-ac97-8472ae8a6faf'),
#  '昆布茶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/82122002-544e-4749-bb91-9f7cc2f20558'),
#  'MIDORI(めろんりきゅーる)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fc26c6fe-e57a-4009-a11a-cb076e89454c'),
#  'すぷらいと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/31b83bcc-b095-41a1-b4bd-7c3ae8f0a74d'),
#  '子どもの頃の記憶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/69e51b90-6af3-45a4-af82-553c8bcbeaf3'),
#  'すーぱーかっぷ(ばにらあいす･100円)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/947b88b9-8b19-427f-9e0b-3ae6e6ed9d1e'),
#  'ぶるがりあよーぐると(100円)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/378990eb-bb8c-4067-91f7-0ae5ccff224b'),
#  'ほーるとまと缶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/524b8a03-972d-4ac6-89e9-a8680a391867'),
#  'かれーるー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/36fa2b91-2578-418c-8455-9ed3e80d3756'),
#  '好きな具材': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6371a8e6-a083-47fc-9eec-f3902d211004'),
#  'まんごー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e0f697d8-5643-4880-b8a4-62a9455d2aeb'),
#  'でぃる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7558bdc5-f10a-459e-9954-963e71614326'),
#  'しぇりー酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a108e94d-c645-4554-a88d-6665f691d93e'),
#  'らいむ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/34d71a43-1554-4511-ab5c-4eaf9082fb3b'),
#  'らいむぺりえ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/610d912b-3445-48a6-a303-3a28277453cb'),
#  'すぺありぶ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0b4e9b0c-fe69-4a1c-afef-046b4a60eb08'),
#  'きゅうい': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b2ac1fab-f9a6-4b7f-b153-6fad82c2308d'),
#  'ますたーど': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c83d1347-c308-40f4-8b0c-865aa27de7cb'),
#  'ふじっ子昆布': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ef1e0646-bb55-4af4-84fa-9c51e3f8f304'),
#  'しらす（じゃこでも良い）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5e11467e-ed8e-4e96-b556-74e24e03a240'),
#  'おかかぱっく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ea6a2bf5-01ac-4577-b6f1-a33aa9cec011'),
#  'ぱいなっぷるじゅーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8db0e914-9f1c-4e37-b9fe-72af91f591fd'),
#  'ここなっつみるく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/026ea2b8-eee9-47cb-93b3-5533ddcd80b7'),
#  'らむ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e443f5bd-aa14-4e96-92bd-93f227d75961'),
#  'いちご': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/421f3a4e-9331-4e71-8a20-d16a82f757d5'),
#  'いちごりきゅーる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d502b333-1cb5-492d-ac40-62d508588cb2'),
#  'たこの足': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cf5a3fa6-b396-4a3b-8d63-fb63c6e36bb4'),
#  '白菜きむち': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2aecae24-3ebe-4bd7-b606-d0f29f8c38dc'),
#  'こちじゃん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0561373d-61ee-4860-bcba-dae9d33c9e5d'),
#  'お酢': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7743029d-7d61-43c9-96a1-69b70708743f'),
#  '白すりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0e1bb0bd-2cfd-4735-95d8-3466a459afc5'),
#  '白いりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1c888ad5-7ff2-4235-9663-a9c0f8528f61'),
#  'ﾊﾟｽﾀ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8d42191e-7d9d-4c78-9187-c81b69c07478'),
#  'ｵｲﾙｻｰﾃﾞｨｰﾝ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9aac8867-f1ee-4b5f-8677-ebcc7a5f8ee5'),
#  'ｵﾘｰﾌﾞｵｲﾙ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fa38ad2c-a7f8-4d6e-aef0-f20bc4107fb2'),
#  'まぐろの赤身': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0ae7db4c-cb9c-46a7-8e9a-d2a77aa315be'),
#  '長芋': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/80138ac7-08cd-487c-b1c9-7a1dd0e0cc6f'),
#  '切り干し大根': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2ceb464e-0ac3-4465-83ce-5a5122c3274c'),
#  '牛薄切り肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fd8a18cb-863b-406f-a168-ba6bb785e998'),
#  '万能ねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/25c75876-6e5a-4c19-bdbb-6bfce5c97691'),
#  'いりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f91cdaf5-6577-43fb-83f6-b8d556313404'),
#  '一味唐辛子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bbcea192-dc6a-494c-a36e-c5416c011db5'),
#  '生しいたけ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f1bc897d-56b3-4753-99a1-6e5ea75b7c27'),
#  '本しめじ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/49844070-2a7a-496f-a1cd-7cf12897b3b5'),
#  '赤唐辛子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f643d85c-954c-4f48-bb2f-76d83df10b54'),
#  '豚薄切り肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9285f153-0996-4acd-a89b-125aa6f937d8'),
#  'さば': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2295dde0-c846-418a-96a9-3a9404135941'),
#  'こんにゃく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9930074f-8cdf-4c45-b9b3-e0ada2dba43f'),
#  'わけぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/11e409f2-9951-43f4-a4af-8e968ed4c3a4'),
#  '赤みそ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/53cb64bc-c11d-4f48-9cb3-39aec292b3a0'),
#  '大根': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a87ac551-bfa6-4fcf-84e3-714638f17ae7'),
#  '薄口しょうゆ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3c12b065-3553-49b1-bcec-857e42322390'),
#  'くるとん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e12c49b2-077c-4d4f-9f21-e287f8f52029'),
#  'E.V.おりーぶおいる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7251177b-4251-46c5-bbcb-1f5b3bfd7552'),
#  'こんそめ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/74b5c0ba-5784-4ed7-8dfb-2256a5c5f91c'),
#  'ほーるこーん缶（つぶ状）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/af30ae91-1af3-4457-8e54-9184156a6876'),
#  'ぐれーぷふるーつ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b42168aa-d845-4b7c-b061-6d39969b441f'),
#  '味の良い塩': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/460232b9-f656-4d09-8fd0-e68b91a5c865'),
#  'ぱせりのみじん切り': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ccaa6f5a-8f41-42ef-8318-52eab3739843'),
#  '茄子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/94386cba-ae75-4f76-940c-2a768781ddb9'),
#  '黄色ぴーまん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/205dd7df-471c-4ca1-b8f9-45ed02d354b2'),
#  '緑ぴーまん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9957441b-81af-406a-a7a5-a9a4529a1945'),
#  '黒胡椒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/436dd709-f416-4b2e-9b26-14722a3a4704'),
#  'おりーぶ油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/63606aad-9f4b-43f4-a0f1-1dc387168435'),
#  'ぱぷりか': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1f24312b-e1c3-4909-a802-d8336cc71ebf'),
#  'すいーとぱじる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fafa5bc4-9d0a-462b-9eb3-549becd0e5c9'),
#  '梅干': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cf979e26-a902-4b6b-8295-270b19006b65'),
#  '鶏肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5fd20a50-2478-4e79-94af-d53e71abd0b4'),
#  'すぱげてぃー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/28d8a7cb-c961-4dd7-b284-6dbf65c14f58'),
#  'あすぱら': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0ac75fb4-a1c0-41ae-acf9-ee0fbbd9cb77'),
#  'なちゅらるちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b8ff2dc8-e12c-45d1-8b28-6ae07cff397c'),
#  'ばるさみこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6be62867-3544-41fe-9ca9-e1e0dbd8ae0a'),
#  'ささみ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bea6c23f-6341-40c5-80db-1f0060b0a62c'),
#  'いんげん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c34a5b1d-9c79-448d-855d-cf5e856747a0'),
#  'うなぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4f6691f6-ecec-40ba-8b2f-12be4020e61a'),
#  '三つ葉ｏｒわけぎ（なければなしで）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ffe487b4-beaa-4088-81fd-56269b228f6d'),
#  'うなぎのたれ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a771be72-1d1b-4376-9919-069dbe94b6e9'),
#  'くれそん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e4c7b89d-3281-470d-9399-3724b22dfd93'),
#  'ちりめんじゃこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/956c6adb-39ad-4676-bc89-8fa18d412f0b'),
#  'ぴーなつ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/68de4c6a-596c-4f9f-813c-a5f4d842561c'),
#  'おかか': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cdfba0d2-1356-4aa7-b146-6135fb68078a'),
#  '和風どれっしんぐ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/346d1fa3-55bf-4331-b3d3-4078a6c94754'),
#  '塩こしょう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e6b5a8f6-c41d-4b54-8935-0cf7c5c5c6ff'),
#  '豚ばら肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f65caab1-a2ba-4d2c-90f8-ebebcb55b99b'),
#  'きな粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/665bf35a-ba76-4f5f-a167-59ae4f6e1029'),
#  'あろえ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/beda967c-ad32-4897-9f50-22c62c598a63'),
#  '豚（ばらでも、ろーすでも）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f8b6f528-abe9-41f6-aad7-83f312547e3b'),
#  '納豆': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f9668a1f-f43c-42f5-b563-27066a32a072'),
#  'ちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2f002fd0-d640-443b-b010-5e48700c635c'),
#  '牛ひき肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8085cc44-17d0-4b32-bbc8-df0b48432f62'),
#  '餃子の皮': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/31ac029d-d43e-46ed-935e-27120ac0bf0f'),
#  'もっちゃれあちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a35245be-598e-43b9-9afa-5bdaa75ce925'),
#  'どれしんぐ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a5ad3ca4-dd50-4fdd-871e-e4f68dd0c667'),
#  'いか': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5d5b4dc7-285f-4a74-a6e8-b3eca47de24c'),
#  '干しえび': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1ec29b5b-dfbc-4f6c-8eae-0e1613ab514f'),
#  'たくあん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5b77feeb-d537-4d49-a445-82edaa1a7503'),
#  'その他': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/50f360fb-0491-4bb9-9049-9a6906283cab'),
#  'かぼちゃ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d992afd1-9993-49a9-a284-75654139537c'),
#  'おれんじ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/91a43727-e527-4d6b-99d2-539c0ddc7b0d'),
#  'びすけっと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c134ce24-6f7a-44df-9492-5ea78b5d0348'),
#  'めんたいこｏｒたらこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/54f0100f-fb25-468c-a09b-ff5081a33384'),
#  'さらだ菜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/88a50fe1-7887-40e1-b187-8f3ef82c9a8f'),
#  'ししゃも': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cc370ce5-8c46-4ab6-8926-63afba402cce'),
#  'すぃーとばじる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d6d2d6d4-95c5-443e-9188-97a9ff8fb562'),
#  'ばるさみこ酢': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/167c3382-c2b4-4837-9185-9f6bd85d4cac'),
#  'わかめ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/96b40bce-762c-4751-90c5-33a411147b78'),
#  '葱': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0c0e3609-3afa-4c58-8765-07348b229a5d'),
#  'かつおだし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/133702c3-0705-4b91-870c-7a32b11320eb'),
#  'えのき茸': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/72d76dda-20d8-4db1-9c9c-474a2cf9e5cb'),
#  '玉子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1169a7c5-5f7d-45c6-a033-9f99208de879'),
#  'きむちの素': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e557fa49-1297-4ce2-b2cf-cea669874e1c'),
#  '肉（鶏か豚）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/352f5611-fed7-42a3-b771-29cee76e6c2c'),
#  '季節の野菜（なす、にんじん、たまねぎ、いんげん、ぴ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9ed33d8a-a5d5-4ab0-9fc2-7d0095ab4536'),
#  'とまと缶（かっと）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ce87d118-8ceb-4fa1-98ed-a696711416e5'),
#  'すーぷの素': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c128d4a7-38c2-4bbc-9ee2-ceecd96a166b'),
#  'とまとけちゃっぷ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/14b84299-1157-4081-9c12-f2d9015940a8'),
#  '料理用わいん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cc504680-0a7c-4621-9bdf-f33575d04378'),
#  'うすたーそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d92a54a1-f0a6-46c9-ba4d-14422c61b2ed'),
#  'にんにくのすりおろし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/cd6b73ca-4e69-4f62-887f-7499b1996fe3'),
#  '塩、こしょう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5c3c8148-43bd-42e8-b5e6-4fed1fe77f24'),
#  'さとうのごはん。': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0f9022d5-0d35-403e-9a3b-4e05306396e7'),
#  'まーがりん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7b3ab120-8dc0-476d-acf3-d9b03df769a7'),
#  'さとうのごはん。または炊きたてごはん。': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6954b715-2721-49e0-bbcf-ddf1ce8857dd'),
#  'きゅぴーまよねーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1c5282ad-ed94-4fda-9fa8-9f31f7a897ff'),
#  '春雨': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e7f88b14-947f-4016-9ae3-c393faaf61cb'),
#  'れたす、きゅうりなどの生食が可能な野菜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/99fdbff1-9fa1-441a-8eb3-f8eb6c75f032'),
#  'みつば': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/59c383eb-415f-466e-8e56-2ce5415677dd'),
#  '削り節（ぱっくのやつ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e48d2429-c627-4a19-a9dd-538f4f62a483'),
# ...
#  'ほうじ茶': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c8b7d00c-4a06-417b-b307-033f21e0c194'),
#  'りんご（紅玉が望ましい）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/455141c1-79c3-41f8-8b2d-4f9a3fdcf9b5'),
#  '食塩': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6dd682b5-61ba-4413-a6a0-e7df8b069144'),
#  nan: rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ae8e0e21-4a1a-4557-9209-4c628be6c372'),
#  'recipe-ingredient': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/463ef314-eabd-43be-ac98-536c7cd6a2d2'),
#  '白身魚': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c5dc4362-2941-4aff-b493-be905330f973'),
#  'ほわいとそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/993c036c-60fa-4e28-8840-22a3e91e2a46'),
#  'すぱの麺': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/44cda08b-a427-4090-8d96-d79397284990'),
#  'ぱせり（乾燥）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a2eb8656-1a4d-47c2-89a9-459dcc8cb691'),
#  'BP': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4541d139-a8bc-4e2b-a25c-2f82824bf2c1'),
#  'すらいすあーもんど': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/491ec7b3-2eb3-4c4e-bd06-c5c26d747f97'),
#  'べ－こん（はむ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5fcb086b-7ffd-4857-93e7-df5d92c34497'),
#  'ぴ－まん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8b239c9c-2db3-4584-bc0c-341d967f614e'),
#  'まよね－ず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/458679f2-285a-41f5-bf3e-53790d734090'),
#  '和風顆粒だしの素': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/06ad41c2-5b80-4c29-a7de-8a632d9373ec'),
#  '塩．こしょう': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ac88a6e0-34f5-470d-86b7-bc5fe49f39be'),
#  '薄力粉．片栗粉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bfeeaf52-9d01-4052-8507-ec550fd78e7e'),
#  'こーひー（濃く入れたもの）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/901757c4-a332-439d-bf71-58bec3275850'),
#  '食ぱん（２～２．５ｃｍ厚さ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/75306fb6-7356-474f-a82a-319e673ab5c3'),
#  'あすぱらがす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/74eb7c9e-371d-42b4-9ecf-78f3ee86b97b'),
#  'おりーぶおいる又は、いたりあんのどれっしんぐ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/62743964-d97b-4480-922a-5374c3843074'),
#  '小麦粉（薄力粉）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5dfe921f-e810-4ece-9da5-c11df98f1432'),
#  'しーちきん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/543ae04b-a88c-40d1-a7cf-f6a8b24b015e'),
#  '削り節': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d007a44d-7827-4274-bc96-6bcc3a5547fd'),
#  '丼汁': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0882b713-f9b4-4a03-8e25-07dc8fc9e39c'),
#  '三つ葉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b87ab48d-9b4e-4415-b106-0fbea22d69b2'),
#  'どっく用ぱん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/383dde70-c1b8-4e81-9b1c-0beb02de18b0'),
#  '豚ばらすらいす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c8261257-71e4-47e0-acc8-0bf73ed77d67'),
#  'てんめん醤': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a30a7d3d-79ec-431b-988f-762905da4266'),
#  'とうち醤': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9475bdfb-aa76-4b7e-89d2-1accc5f6605d'),
#  'ＸＯ醤': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/49d0f042-74d9-43bb-94ec-00d3d33fc7be'),
#  '老酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c4374cd8-3737-4f69-9265-fa1c89de0554'),
#  '簡単しちゅー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/41103463-c68d-4f02-a4ff-20cff665e390'),
#  'ぱいしーと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e5a4c86a-1970-4192-829c-f2ad80721908'),
#  'すらいすちーず（とろけるもの）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4c4bb05e-52b1-4ff8-afe5-6afd9dc5f004'),
#  '海苔': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3010184f-ad53-472d-9f4a-4e7cff6e5e22'),
#  'いーすと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/991c7cc2-aa8d-43ba-9c4d-0bdad11583b4'),
#  '市販のぴざそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/154089ff-76c7-4b22-95d9-1bd8b7c964b2'),
#  '豚肉（ばら・すぺありぶ等）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c4b1b09b-aa38-498c-944f-abfd1dd44aa9'),
#  'お醤油': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/679d66a4-b1f6-459d-86b5-1a2a5f5eb736'),
#  'ぷろせすちーず': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2d821620-98d3-4ef2-9fe5-537ed2a82d31'),
#  '昆布の佃煮': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1ab747e1-7fda-47f9-86db-af64cde8ec6e'),
#  '辛子明太子': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2316d25d-b0af-4fab-8302-a9081a92a5fc'),
#  '豚ばら薄切り肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/24daccf1-b31a-4bf7-9752-c3274719a9a1'),
#  'ｺﾁｭじゃん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/dbf13723-11bf-4be8-bdae-5c62b13a0199'),
#  'みそ(あれば米こうじ)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2356d959-033e-43fa-a974-02550af6066e'),
#  '玄米': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3170bef1-c03f-4a79-989e-1910b6809093'),
#  'たると生地': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/b73c7fc9-14c3-4628-ad79-f20a01628103'),
#  'せみすいーとちょこれーと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7aedd5e5-9f01-4c96-b7d6-7b80255e4e81'),
#  '全卵': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d88f5981-4158-4da8-9fe3-75ea2d9d989d'),
#  'あればあぷりこっとじゃむ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/25daeef9-e1a5-461c-b284-ed6cfca8d614'),
#  '市販のたると台': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c99058c0-19f3-4c77-bba6-6d0818c613fb'),
#  '粉糖': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4ca79757-9ef5-4eef-8912-4c2598743147'),
#  'かってーじちーず（裏ごしたいぷ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8a74dee3-9ad3-4679-9421-eceac26aa5fd'),
#  'ぶるざんちーず（ぺっぱー味）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e70e9460-406a-4564-8c91-15115a3cb9fb'),
#  'くらっかー(くらこっとがべすと）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4dcec72b-bcfd-42bc-ae54-52455d15213e'),
#  'ぴーなつばたー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8ef80631-f6aa-4521-aafe-ee2de2923b4f'),
#  'ぶり切り身': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e97a7bef-a6a8-48a3-8bc4-cbc6ed908249'),
#  '餅': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2ad3823b-2044-42ab-b9ad-b65f13859f3f'),
#  '七味': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/87df8a58-4ea8-44b4-9ac2-cd55350c046b'),
#  '鳥か豚のひき肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/95b21149-8715-4dd5-acb0-84efd2d15c76'),
#  '豚みんち': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e386d062-b391-4fbf-93e5-9c960958a6d2'),
#  '醤油塩': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3fff1a9f-93e7-459c-994e-3f786b0917ae'),
#  '白滝': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f1a67a31-15b4-4983-924e-05bf00c837c1'),
#  'お水': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/78eaad94-b9fc-4882-ae41-05350e20ba8b'),
#  '麺つゆ（３倍濃縮のもの）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6f9a4534-b193-4685-9798-40efd009cf8b'),
#  'お餅': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5f41dc93-8b4c-4caf-8d27-5294f02ec179'),
#  'かぶ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/17e98ea2-a978-4f60-99fe-11a8e35c572d'),
#  'すぱげってぃー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/31784dbd-1a52-4324-9279-233038144a43'),
#  '缶こーん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/74c67f3f-1677-4274-9463-48ba7b7b5db3'),
#  'すぱげってぃーに': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4291ae88-7f99-442c-b75e-8bac67e51d57'),
#  'ぱるめじゃーの・れじゃーの': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0514bb97-789f-4b1f-943b-51246a0c6a45'),
#  '挽肉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7295f282-e699-4d2a-a7c5-6421c82de76b'),
#  '鶏': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1b59d6c9-7a92-48e4-a8f1-983331a4ae16'),
#  'ぴめんと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/37f3620d-359f-4313-89e4-63b3522d3eda'),
#  'とまとぺーすと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9a4f2080-1501-4f37-81d6-e672113fe3a7'),
#  'こんそめきゅーぶ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/76f9f65a-3601-4b58-b791-b9e1f1e4fc88'),
#  'ちりぱうだー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7e30b552-bc93-4f61-9bd4-89b6f44b246f'),
#  '塩、胡椒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/db0341fb-bcda-4627-ac17-3bfd7af2c2fa'),
#  'ぴーなっつ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a917e373-bce6-45f4-afe9-1158e4781121'),
#  '鶏皮': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/3c3377e8-91c3-4876-b449-83d3de6e4b9b'),
#  'しらがねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2f21abae-431c-4065-9575-2078fe133fae'),
#  '鶏胸肉（皮なし）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/ed9b2e59-836c-41ec-90b8-be2ff8237c16'),
#  'とまとそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/103692a4-451b-48e6-9388-e01981c104cf'),
#  'ふれっしゅばじる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8bd2a1c1-5037-4848-bac7-a5377ecae246'),
#  'おれきえって': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/134911cf-8f1b-4d34-a0b8-5d7d58fc39ef'),
#  '豚もも薄切': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6a7e497d-0dcb-4b11-b3f8-f65144ec6650'),
#  '長ねぎ（細切り）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/422c9b2c-89c4-4e3a-bc8f-1bd6b66d1bae'),
#  '生姜（針生姜）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e39a5145-7b9d-4808-96ac-15a5128e2474'),
#  'しらす干': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1484706e-2add-4f43-9805-d22a195332c4'),
#  '砂糖（なくても可）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/be425ad0-d376-439c-bc1b-1baf649926a0'),
#  '酒（なくても可）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/bdf7f90e-d109-4726-b4f7-6309a61c5a5d'),
#  '濃口しょうゆ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0d8aa81a-8d23-4474-a230-841410e47631'),
#  'おれんじま－まれ－ど': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/6726a26e-82f8-4b3d-8673-5e0ea3590d5c'),
#  'ふらんすぱん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/73de807d-854d-4525-95bf-ab0e4795006a'),
#  'ばたーまたはまーがりん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/805a5e5f-cfef-4089-a5c7-b836e8011574'),
#  'がーりっくぱうだー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/052fe45e-0819-43e9-9fc4-04ba308e4ce5'),
#  'おろしたにんじん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/292e2e94-0d32-4f3c-b896-79b21d64f94a'),
#  '細かく砕いたくるみ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/36aa9152-a2c7-426b-9434-79d6e07a7223'),
#  'ぐらにゅう糖': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/06aea38c-365b-463f-b87d-7cb82a2bd013'),
#  'ねりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/4ad868cd-9d42-42ac-b731-3ed9eb2e61b9'),
#  '小松菜': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f0b56101-0e7f-4657-aa24-098ecaf866af'),
#  'ごまだれ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/912ba1bc-b22e-4eab-bff4-beefbedb287b'),
#  '白だし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/70f946f5-34b3-4766-b101-580154b75a9d'),
#  '鶏手羽': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e8e98725-685c-4cf0-b083-e082abc60cec'),
#  'こんそめ（顆粒）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0dbeb84b-f055-4005-a510-1e1171f46310'),
#  '細めのぱすた': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a9fcd62d-e415-4e02-b195-92baf528063d'),
#  '生のばじる': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/18e7a297-4aff-45df-a418-4465d4839c37'),
#  '牛もも肉（かたまり）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a1167c85-29b6-4ae9-b09c-0e0fc6c41c2a'),
#  '濃く入れた紅茶液': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7897bdc4-0163-4968-88a2-5629eaa2c850'),
#  'てぃーぱっく': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/d60857c0-5504-49ae-9164-1ea374af99f7'),
#  '牛もも肉かたまり': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/fa02d759-41d2-4ef5-98c7-4a221cd1667a'),
#  'お好みのきのこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f1211845-f2d0-4103-ab17-3721ee1ff850'),
#  '市販のかれーるー': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f6cc6aee-8d04-4aea-8e25-4ac76cc9ad27'),
#  '炒めたまねぎぺーすと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5d4a0aba-2cfb-4e08-8843-9c4b73955ae6'),
#  'じゃがいも・めーくいん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a6621ed4-3f9f-4da8-ae95-5b3a576c1025'),
#  'ながねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/dc55eee5-f623-45c5-a612-3c7cbfdfb88e'),
#  'すーぷのもと': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/aeb1ff36-e337-4774-a3dd-567dcb00a4de'),
#  '塩・砂糖': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/afa47355-0dd1-43e0-a7a5-3636f0c196c2'),
#  '小玉ねぎ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/9063f614-e3e1-49c5-93cb-6b94c0de3e72'),
#  'さふらん': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a8ebd301-122d-4f8e-9272-3e166c495eff'),
#  '牛肉の薄切り': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/34310a90-621d-439c-8076-71f23cce24af'),
#  'ゆり根': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5c9084ef-85e8-4fad-aeec-bc9494a41211'),
#  '酒かす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/c1ba0e84-3c2f-4823-bb7a-07c00f0a49ca'),
#  '梅酒': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7d0a1157-d485-4a48-b501-bcbff073c690'),
#  '出し汁': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/61f0026b-65b3-4a12-84cb-d9e586529f8f'),
#  '鶏ささみ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/e2b139a5-53a5-411b-ba09-548442e0f40d'),
#  '玄米ご飯（普通のご飯でも可）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/981df992-ce8f-49d3-b177-02bcb7368056'),
#  '甘塩たら': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5dd406d6-c7a8-4711-ac48-c3080bb97f6a'),
#  '水煮たけのこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/2568b83d-3027-426e-b6d5-67188eb37bca'),
#  '味海苔': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/07baf226-14ca-4d4a-bb30-a9511188c9b7'),
#  'あさり（むきみ）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/a1b3c8dd-e2ba-44cb-8bc1-aec77c9fdaa1'),
#  '当たりごま': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/55dde534-c7e4-44dc-bb97-b031d57b4d1b'),
#  'むき海老': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/291a47f2-e915-4cf1-ac27-54b106a846a1'),
#  'ゆでそば': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/7428e949-93e5-4a5f-92c2-cea4ceeb54ec'),
#  'かまぼこ': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/0f9d7a3a-85a1-43e8-aa6f-e419ddec4746'),
#  'きゃべつの葉': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/32da0963-6be3-4190-965c-6e8199fdf86e'),
#  '鶏みんち': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/16ea363d-20ac-4f53-bc1d-0438e8015950'),
#  'ちーず（好きなもの）': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/592064cd-4266-44bd-989b-d2aeccad7c9e'),
#  '(ぴざ用ちーず)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/de823247-11be-4440-8c44-f8691e150dc2'),
#  '(にら)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/f426e398-98b3-450a-bcd5-fa045894c087'),
#  '(もろへいや)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/06f35906-4fa8-40a9-8a14-34cf91d8deae'),
#  'とんかつそーす': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/872c9aca-17f9-47d8-b581-2b86a9ca13de'),
#  '(まよねーず)': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/8fc649a4-4dd2-439e-b04a-6ea0832a1c93'),
#  'ぶりのあら': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5267ac4b-f8ff-4a45-9c83-415b56ea5a08'),
#  '鶏の皮': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/1965fa31-fd8f-4183-9819-f77ff6d599f4'),
#  '粉末かつおだし': rdflib.term.URIRef('http://JapaneseFoodKG.org/Ingredient/5b9fb4c8-24dd-4f98-83d7-983f40fe6386'),
#  ...}
