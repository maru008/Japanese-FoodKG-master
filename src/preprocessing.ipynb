# %%
import pandas as pd

# %%
seibun_data = pd.read_excel("../data/Japanese_Nutrition_Data/1365334_1r12.xlsx","本表")

# %%
seibun_data
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0     日本食品標準成分表2015年版（七訂）        NaN        NaN  \
# 1                      本表        NaN        NaN
# 2                     NaN        NaN        NaN
# 3                     食品群       食品番号       索引番号
# 4                     NaN        NaN        NaN
# ...                   ...        ...        ...
# 2193                   18      18013       2194
# 2194                   18      18014       2195
# 2195                   18      18015       2196
# 2196                   18      18016       2197
# 2197                   18      18022       2198
#
#                                     Unnamed: 3 Unnamed: 4   Unnamed: 5
# 0                                          NaN        NaN          NaN  \
# 1     文字列として入力されてデータがありますので、計算等に使用される場合はご注意下さい        NaN          NaN
# 2                                          NaN        NaN          NaN
# 3                                          食品名      廃 棄 率          NaN
# ...
